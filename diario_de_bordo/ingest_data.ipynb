# %% [markdown]
# # **Ingest Data Process**

# %% [markdown]
# ## Dependencies and Parameters

# %%
import pandas as pd

# %%
path = "/Users/andrebezerra/Desktop/Dev/DesafiosCodeElevate/diario_de_bordo/info_transportes.csv"
parquet_path = "/Users/andrebezerra/Desktop/Dev/DesafiosCodeElevate/diario_de_bordo/transportes.parquet"

# %%
df = pd.read_csv(path, sep=";")
display(df)

# Salvar no formato Parquet (compatível com Delta Lake)
df.to_parquet(parquet_path, engine="pyarrow", index=False)

print("Dados normalizados e salvos em formato Parquet com sucesso!")
# Out:
#            DATA_INICIO          DATA_FIM CATEGORIA      LOCAL_INICIO  \
# 0     01-01-2016 21:11  01-01-2016 21:17   Negocio       Fort Pierce
# 1     01-02-2016 01:25  01-02-2016 01:37   Negocio       Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38   Negocio       Fort Pierce
# 3     01-05-2016 17:31  01-05-2016 17:45   Negocio       Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49   Negocio       Fort Pierce
# ...                ...               ...       ...               ...
# 1148   12-31-2016 1:07   12-31-2016 1:14   Negocio            Karchi
# 1149  12-31-2016 13:24  12-31-2016 13:42   Negocio            Karchi
# 1150  12-31-2016 15:03  12-31-2016 15:38   Negocio  Unknown Location
# 1151  12-31-2016 21:32  12-31-2016 21:50   Negocio        Katunayake
# 1152  12-31-2016 22:08  12-31-2016 23:51   Negocio           Gampaha
#
#              LOCAL_FIM  DISTANCIA          PROPOSITO
# 0          Fort Pierce         51        Alimentação
# 1          Fort Pierce          5                NaN
# 2          Fort Pierce         48           Entregas
# 3          Fort Pierce         47            Reunião
# 4      West Palm Beach        637  Visita ao cliente
# ...                ...        ...                ...
# 1148            Karchi          7            Reunião
# 1149  Unknown Location         39  Parada temporária
# 1150  Unknown Location        162            Reunião
# 1151           Gampaha         64  Parada temporária
# 1152         Ilukwatta        482  Parada temporária
#
# [1153 rows x 7 columns]
# Dados normalizados e salvos em formato Parquet com sucesso!
